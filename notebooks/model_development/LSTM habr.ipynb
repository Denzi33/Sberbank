# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
# %run ../preset.py

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size

    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i)
        # Reshape data from (history_size,) to (history_size, 1)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
    
    return np.array(data), np.array(labels)

# %%
tf.random.set_seed(13)

# %%
df = pd.read_parquet("../../prepare_data/data.gzip")

# %%
df
# Out:
#                                        subject_name  actual_consumption  \
# index
# 2011-01-01 00:00:00                  Алтайский край              1313.0
# 2011-01-01 00:00:00                Амурская область               870.0
# 2011-01-01 00:00:00           Архангельская область               970.0
# 2011-01-01 00:00:00            Астраханская область               504.0
# 2011-01-01 00:00:00            Белгородская область              1592.0
# ...                                             ...                 ...
# 2024-07-17 00:00:00             Челябинская область              3854.0
# 2024-07-17 00:00:00            Чеченская Республика               412.0
# 2024-07-17 00:00:00  Чувашская Республика - Чувашия               486.0
# 2024-07-17 00:00:00       Южно-Якутский энергорайон               358.0
# 2024-07-17 00:00:00             Ярославская область               766.0
#
#                                 datetime
# index
# 2011-01-01 00:00:00  2011-01-01 00:00:00
# 2011-01-01 00:00:00  2011-01-01 00:00:00
# 2011-01-01 00:00:00  2011-01-01 00:00:00
# 2011-01-01 00:00:00  2011-01-01 00:00:00
# 2011-01-01 00:00:00  2011-01-01 00:00:00
# ...                                  ...
# 2024-07-17 00:00:00  2024-07-17 00:00:00
# 2024-07-17 00:00:00  2024-07-17 00:00:00
# 2024-07-17 00:00:00  2024-07-17 00:00:00
# 2024-07-17 00:00:00  2024-07-17 00:00:00
# 2024-07-17 00:00:00  2024-07-17 00:00:00
#
# [8478449 rows x 3 columns]

# %%
df.drop(columns=["datetime"], inplace=True)

# %%
df
# Out:
#                                        subject_name  actual_consumption
# index
# 2011-01-01 00:00:00                  Алтайский край              1313.0
# 2011-01-01 00:00:00                Амурская область               870.0
# 2011-01-01 00:00:00           Архангельская область               970.0
# 2011-01-01 00:00:00            Астраханская область               504.0
# 2011-01-01 00:00:00            Белгородская область              1592.0
# ...                                             ...                 ...
# 2024-07-17 00:00:00             Челябинская область              3854.0
# 2024-07-17 00:00:00            Чеченская Республика               412.0
# 2024-07-17 00:00:00  Чувашская Республика - Чувашия               486.0
# 2024-07-17 00:00:00       Южно-Якутский энергорайон               358.0
# 2024-07-17 00:00:00             Ярославская область               766.0
#
# [8478449 rows x 2 columns]

# %%
tmp = pd.get_dummies(df["subject_name"])

# %%
tmp.head(3)
# Out:
#                      Алтайский край  Амурская область  Архангельская область  \
# index
# 2011-01-01 00:00:00               1                 0                      0
# 2011-01-01 00:00:00               0                 1                      0
# 2011-01-01 00:00:00               0                 0                      1
#
#                      Астраханская область  Белгородская область  \
# index
# 2011-01-01 00:00:00                     0                     0
# 2011-01-01 00:00:00                     0                     0
# 2011-01-01 00:00:00                     0                     0
#
#                      Брянская область  Владимирская область  \
# index
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
#
#                      Волгоградская область  Вологодская область  \
# index
# 2011-01-01 00:00:00                      0                    0
# 2011-01-01 00:00:00                      0                    0
# 2011-01-01 00:00:00                      0                    0
#
#                      Воронежская область  ...  Тульская область  \
# index                                     ...
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
#
#                      Тюменская область  Удмуртская Республика  \
# index
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
#
#                      Ульяновская область  Центральный энергорайон Якутии  \
# index
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
#
#                      Челябинская область  Чеченская Республика  \
# index
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
#
#                      Чувашская Республика - Чувашия  \
# index
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
#
#                      Южно-Якутский энергорайон  Ярославская область
# index
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
#
# [3 rows x 75 columns]

# %%
df = pd.concat([df, tmp], axis=1)

# %%
df
# Out:
#                                        subject_name  actual_consumption  \
# index
# 2011-01-01 00:00:00                  Алтайский край              1313.0
# 2011-01-01 00:00:00                Амурская область               870.0
# 2011-01-01 00:00:00           Архангельская область               970.0
# 2011-01-01 00:00:00            Астраханская область               504.0
# 2011-01-01 00:00:00            Белгородская область              1592.0
# ...                                             ...                 ...
# 2024-07-17 00:00:00             Челябинская область              3854.0
# 2024-07-17 00:00:00            Чеченская Республика               412.0
# 2024-07-17 00:00:00  Чувашская Республика - Чувашия               486.0
# 2024-07-17 00:00:00       Южно-Якутский энергорайон               358.0
# 2024-07-17 00:00:00             Ярославская область               766.0
#
#                      Алтайский край  Амурская область  Архангельская область  \
# index
# 2011-01-01 00:00:00               1                 0                      0
# 2011-01-01 00:00:00               0                 1                      0
# 2011-01-01 00:00:00               0                 0                      1
# 2011-01-01 00:00:00               0                 0                      0
# 2011-01-01 00:00:00               0                 0                      0
# ...                             ...               ...                    ...
# 2024-07-17 00:00:00               0                 0                      0
# 2024-07-17 00:00:00               0                 0                      0
# 2024-07-17 00:00:00               0                 0                      0
# 2024-07-17 00:00:00               0                 0                      0
# 2024-07-17 00:00:00               0                 0                      0
#
#                      Астраханская область  Белгородская область  \
# index
# 2011-01-01 00:00:00                     0                     0
# 2011-01-01 00:00:00                     0                     0
# 2011-01-01 00:00:00                     0                     0
# 2011-01-01 00:00:00                     1                     0
# 2011-01-01 00:00:00                     0                     1
# ...                                   ...                   ...
# 2024-07-17 00:00:00                     0                     0
# 2024-07-17 00:00:00                     0                     0
# 2024-07-17 00:00:00                     0                     0
# 2024-07-17 00:00:00                     0                     0
# 2024-07-17 00:00:00                     0                     0
#
#                      Брянская область  Владимирская область  \
# index
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
# 2011-01-01 00:00:00                 0                     0
# ...                               ...                   ...
# 2024-07-17 00:00:00                 0                     0
# 2024-07-17 00:00:00                 0                     0
# 2024-07-17 00:00:00                 0                     0
# 2024-07-17 00:00:00                 0                     0
# 2024-07-17 00:00:00                 0                     0
#
#                      Волгоградская область  ...  Тульская область  \
# index                                       ...
# 2011-01-01 00:00:00                      0  ...                 0
# 2011-01-01 00:00:00                      0  ...                 0
# 2011-01-01 00:00:00                      0  ...                 0
# 2011-01-01 00:00:00                      0  ...                 0
# 2011-01-01 00:00:00                      0  ...                 0
# ...                                    ...  ...               ...
# 2024-07-17 00:00:00                      0  ...                 0
# 2024-07-17 00:00:00                      0  ...                 0
# 2024-07-17 00:00:00                      0  ...                 0
# 2024-07-17 00:00:00                      0  ...                 0
# 2024-07-17 00:00:00                      0  ...                 0
#
#                      Тюменская область  Удмуртская Республика  \
# index
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# ...                                ...                    ...
# 2024-07-17 00:00:00                  0                      0
# 2024-07-17 00:00:00                  0                      0
# 2024-07-17 00:00:00                  0                      0
# 2024-07-17 00:00:00                  0                      0
# 2024-07-17 00:00:00                  0                      0
#
#                      Ульяновская область  Центральный энергорайон Якутии  \
# index
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# ...                                  ...                             ...
# 2024-07-17 00:00:00                    0                               0
# 2024-07-17 00:00:00                    0                               0
# 2024-07-17 00:00:00                    0                               0
# 2024-07-17 00:00:00                    0                               0
# 2024-07-17 00:00:00                    0                               0
#
#                      Челябинская область  Чеченская Республика  \
# index
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# ...                                  ...                   ...
# 2024-07-17 00:00:00                    1                     0
# 2024-07-17 00:00:00                    0                     1
# 2024-07-17 00:00:00                    0                     0
# 2024-07-17 00:00:00                    0                     0
# 2024-07-17 00:00:00                    0                     0
#
#                      Чувашская Республика - Чувашия  \
# index
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# ...                                             ...
# 2024-07-17 00:00:00                               0
# 2024-07-17 00:00:00                               0
# 2024-07-17 00:00:00                               1
# 2024-07-17 00:00:00                               0
# 2024-07-17 00:00:00                               0
#
#                      Южно-Якутский энергорайон  Ярославская область
# index
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# ...                                        ...                  ...
# 2024-07-17 00:00:00                          0                    0
# 2024-07-17 00:00:00                          0                    0
# 2024-07-17 00:00:00                          0                    0
# 2024-07-17 00:00:00                          1                    0
# 2024-07-17 00:00:00                          0                    1
#
# [8478449 rows x 77 columns]

# %%
df.drop(columns=["subject_name"], inplace=True)

# %%
df.head(3)
# Out:
#                      actual_consumption  Алтайский край  Амурская область  \
# index
# 2011-01-01 00:00:00              1313.0               1                 0
# 2011-01-01 00:00:00               870.0               0                 1
# 2011-01-01 00:00:00               970.0               0                 0
#
#                      Архангельская область  Астраханская область  \
# index
# 2011-01-01 00:00:00                      0                     0
# 2011-01-01 00:00:00                      0                     0
# 2011-01-01 00:00:00                      1                     0
#
#                      Белгородская область  Брянская область  \
# index
# 2011-01-01 00:00:00                     0                 0
# 2011-01-01 00:00:00                     0                 0
# 2011-01-01 00:00:00                     0                 0
#
#                      Владимирская область  Волгоградская область  \
# index
# 2011-01-01 00:00:00                     0                      0
# 2011-01-01 00:00:00                     0                      0
# 2011-01-01 00:00:00                     0                      0
#
#                      Вологодская область  ...  Тульская область  \
# index                                     ...
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
#
#                      Тюменская область  Удмуртская Республика  \
# index
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
#
#                      Ульяновская область  Центральный энергорайон Якутии  \
# index
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
#
#                      Челябинская область  Чеченская Республика  \
# index
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
#
#                      Чувашская Республика - Чувашия  \
# index
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
#
#                      Южно-Якутский энергорайон  Ярославская область
# index
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
#
# [3 rows x 76 columns]

# %%
cons_mean = df["actual_consumption"].mean()

# %%
cons_std = df["actual_consumption"].std()

# %%
cons_std
# Out:
# 2127.9075776424816

# %%
df["actual_consumption"] = (df["actual_consumption"] - cons_mean) / cons_std

# %%
df["actual_consumption"]
# Out:
# index
# 2011-01-01 00:00:00   -0.382962
# 2011-01-01 00:00:00   -0.591148
# 2011-01-01 00:00:00   -0.544153
# 2011-01-01 00:00:00   -0.763148
# 2011-01-01 00:00:00   -0.251847
#                          ...
# 2024-07-17 00:00:00    0.811169
# 2024-07-17 00:00:00   -0.806383
# 2024-07-17 00:00:00   -0.771607
# 2024-07-17 00:00:00   -0.831760
# 2024-07-17 00:00:00   -0.640022
# Name: actual_consumption, Length: 8478449, dtype: float64

# %%
df.head(3)
# Out:
#                      actual_consumption  Алтайский край  Амурская область  \
# index
# 2011-01-01 00:00:00           -0.382962               1                 0
# 2011-01-01 00:00:00           -0.591148               0                 1
# 2011-01-01 00:00:00           -0.544153               0                 0
#
#                      Архангельская область  Астраханская область  \
# index
# 2011-01-01 00:00:00                      0                     0
# 2011-01-01 00:00:00                      0                     0
# 2011-01-01 00:00:00                      1                     0
#
#                      Белгородская область  Брянская область  \
# index
# 2011-01-01 00:00:00                     0                 0
# 2011-01-01 00:00:00                     0                 0
# 2011-01-01 00:00:00                     0                 0
#
#                      Владимирская область  Волгоградская область  \
# index
# 2011-01-01 00:00:00                     0                      0
# 2011-01-01 00:00:00                     0                      0
# 2011-01-01 00:00:00                     0                      0
#
#                      Вологодская область  ...  Тульская область  \
# index                                     ...
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
# 2011-01-01 00:00:00                    0  ...                 0
#
#                      Тюменская область  Удмуртская Республика  \
# index
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
# 2011-01-01 00:00:00                  0                      0
#
#                      Ульяновская область  Центральный энергорайон Якутии  \
# index
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
# 2011-01-01 00:00:00                    0                               0
#
#                      Челябинская область  Чеченская Республика  \
# index
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
# 2011-01-01 00:00:00                    0                     0
#
#                      Чувашская Республика - Чувашия  \
# index
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
# 2011-01-01 00:00:00                               0
#
#                      Южно-Якутский энергорайон  Ярославская область
# index
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
# 2011-01-01 00:00:00                          0                    0
#
# [3 rows x 76 columns]

# %%
def multivariate_data(
                      dataset,
                      target,
                      start_index,
                      end_index,
                      history_size,
                      target_size,
                      step,
                      single_step=False
):

    data = []
    labels = []

    start_index = start_index + history_size

    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

    if single_step:
        labels.append(target[i+target_size])
    else:
        labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
dataset = df.drop(columns=["actual_consumption"])

# %%
target = df["actual_consumption"]

# %%
past_history = 670000 # На неделю
future_target = 25200
STEP = 24
TRAIN_SPLIT = 300000

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 1)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[45], line 6
#       3 STEP = 24
#       4 TRAIN_SPLIT = 300000
# ----> 6 x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
#       7                                                    TRAIN_SPLIT, past_history,
#       8                                                    future_target, STEP,
#       9                                                    single_step=True)
#      10 x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
#      11                                                TRAIN_SPLIT, None, past_history,
#      12                                                future_target, STEP,
#      13                                                single_step=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key, method, tolerance)
#    3804         raise KeyError(key) from err
#    3805     except TypeError:
#    3806         # If we have a listlike key, _check_indexing_error will raise
#    3807         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808         #  the TypeError.
# -> 3809         self._check_indexing_error(key)
#    3810         raise
#    3812 # GH#42269
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5921 def _check_indexing_error(self, key):
#    5922     if not is_scalar(key):
#    5923         # if key is not a scalar, directly raise an error (the code below
#    5924         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 1)
